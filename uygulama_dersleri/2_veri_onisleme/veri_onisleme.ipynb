# %%
# !conda list
# Out:
# # packages in environment at C:\Users\FBE\Anaconda3:
# #
# # Name                    Version                   Build  Channel
# _ipyw_jlab_nb_ext_conf    0.1.0                    py37_0
# alabaster                 0.7.12                   py37_0
# anaconda                  2019.10                  py37_0
# anaconda-client           1.7.2                    py37_0
# anaconda-navigator        1.9.7                    py37_0
# anaconda-project          0.8.3                      py_0
# anyqt                     0.0.10                   py37_0
# asn1crypto                1.0.1                    py37_0
# astroid                   2.3.1                    py37_0
# astropy                   3.2.1            py37he774522_0
# atomicwrites              1.3.0                    py37_1
# attrs                     19.2.0                     py_0
# autopep8                  1.4.4                      py_0
# babel                     2.7.0                      py_0
# ...

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("data\\employees.csv")

# %%
df.head(10)
# Out:
#   First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 5     Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 6       Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 7        NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 8     Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 9    Frances  Female    8/8/2002         6:51 AM  139852    7.524
#
#   Senior Management                  Team
# 0              True             Marketing
# 1              True                   NaN
# 2             False               Finance
# 3              True               Finance
# ...

# %%
df.tail()
# Out:
#     First Name Gender  Start Date Last Login Time  Salary  Bonus %  \
# 995      Henry    NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip   Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell   Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry   Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert   Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 995             False          Distribution
# 996             False               Finance
# 997             False               Product
# 998             False  Business Development
# 999              True                 Sales

# %%
df['Gender']
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3        Male
# 4        Male
#         ...
# 995       NaN
# 996      Male
# 997      Male
# 998      Male
# 999      Male
# Name: Gender, Length: 1000, dtype: object

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null object
# Start Date           1000 non-null object
# Last Login Time      1000 non-null object
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    933 non-null object
# Team                 957 non-null object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
df.describe()
# Out:
#               Salary      Bonus %
# count    1000.000000  1000.000000
# mean    90662.181000    10.207555
# std     32923.693342     5.528481
# min     35013.000000     1.015000
# 25%     62613.000000     5.401750
# 50%     90428.000000     9.838500
# 75%    118740.250000    14.838000
# max    149908.000000    19.944000

# %%
df.iloc[0]
# Out:
# First Name             Douglas
# Gender                    Male
# Start Date            8/6/1993
# Last Login Time       12:42 PM
# Salary                   97308
# Bonus %                  6.945
# Senior Management         True
# Team                 Marketing
# Name: 0, dtype: object

# %%
df.loc[0:2,'Gender']
# Out:
# 0      Male
# 1      Male
# 2    Female
# Name: Gender, dtype: object

# %%
df.iloc[0:3,1]
# Out:
# 0      Male
# 1      Male
# 2    Female
# Name: Gender, dtype: object

# %%
df[df.Salary<130000]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 4        Larry    Male  1/24/1998         4:47 PM  101004    1.389
# 5       Dennis    Male  4/18/1987         1:35 AM  115163   10.125
# 6         Ruby  Female  8/17/1987         4:20 PM   65476   10.012
# ..         ...     ...        ...             ...     ...      ...
# 994     George    Male  6/21/2013         5:47 PM   98874    4.479
# 996    Phillip    Male  1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male  5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male  4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male  5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
df.Salary<130000
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4       True
#        ...
# 995    False
# 996     True
# 997     True
# 998     True
# 999     True
# Name: Salary, Length: 1000, dtype: bool

# %%
df['Gender']
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3        Male
# 4        Male
#         ...
# 995       NaN
# 996      Male
# 997      Male
# 998      Male
# 999      Male
# Name: Gender, Length: 1000, dtype: object

# %%
df.Gender
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3        Male
# 4        Male
#         ...
# 995       NaN
# 996      Male
# 997      Male
# 998      Male
# 999      Male
# Name: Gender, Length: 1000, dtype: object

# %%
df.iloc[0:5,3:]
# Out:
#   Last Login Time  Salary  Bonus % Senior Management             Team
# 0        12:42 PM   97308    6.945              True        Marketing
# 1         6:53 AM   61933    4.170              True              NaN
# 2        11:17 AM  130590   11.858             False          Finance
# 3         1:00 PM  138705    9.340              True          Finance
# 4         4:47 PM  101004    1.389              True  Client Services

# %%
df['total_revenue']=df.Salary + df['Bonus %']

# %%
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team  total_revenue
# 0              True        Marketing      97314.945
# 1              True              NaN      61937.170
# 2             False          Finance     130601.858
# 3              True          Finance     138714.340
# 4              True  Client Services     101005.389

# %%
df.total_revenue = df.total_revenue*100

# %%
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team  total_revenue
# 0              True        Marketing      9731494.5
# 1              True              NaN      6193717.0
# 2             False          Finance     13060185.8
# 3              True          Finance     13871434.0
# 4              True  Client Services     10100538.9

# %%
df.to_csv("employees2.csv")

# %%
df.isnull().sum()
# Out:
# First Name            67
# Gender               145
# Start Date             0
# Last Login Time        0
# Salary                 0
# Bonus %                0
# Senior Management     67
# Team                  43
# total_revenue          0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# First Name            933
# Gender                855
# Start Date           1000
# Last Login Time      1000
# Salary               1000
# Bonus %              1000
# Senior Management     933
# Team                  957
# total_revenue        1000
# dtype: int64

# %%
eksik_olmayan_filtre = pd.notnull(df.Team)

# %%
eksik_olmayan_filtre
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 995     True
# 996     True
# 997     True
# 998     True
# 999     True
# Name: Team, Length: 1000, dtype: bool

# %%
df_takim_degerleri_dolu = df[eksik_olmayan_filtre]

# %%
df_takim_degerleri_dolu
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 5       Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team  total_revenue
# 0                True             Marketing      9731494.5
# ...

# %%
df_takim_degerleri_dolu
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 5       Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team  total_revenue
# 0                True             Marketing      9731494.5
# ...

# %%
df[df.Team=='Marketing']
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 21     Matthew    Male    9/5/1995         2:12 AM  100612   13.645
# 26       Craig    Male   2/27/2000         7:45 AM   37598    7.757
# 43     Marilyn  Female   12/7/1980         3:16 AM   73524    5.207
# 62         NaN  Female   6/12/2007         5:25 PM   58112   19.414
# ..         ...     ...         ...             ...     ...      ...
# 942       Lori  Female  11/20/2015         1:15 PM   75498    6.537
# 947        NaN    Male   7/30/2012         3:07 PM  107351    5.329
# 986      Donna  Female  11/26/1982         7:04 AM   82871   17.999
# 991       Rose  Female   8/25/2002         5:12 AM  134505   11.051
# 994     George    Male   6/21/2013         5:47 PM   98874    4.479
#
#     Senior Management       Team  total_revenue
# 0                True  Marketing      9731494.5
# 21              False  Marketing     10062564.5
# ...
